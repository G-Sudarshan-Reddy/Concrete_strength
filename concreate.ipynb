# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Concrete_Data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse_Aggregate  Fine_Aggregate  Age  Concrete_strength
# 0               1040.0           676.0   28              79.99
# 1               1055.0           676.0   28              61.89
# 2                932.0           594.0  270              40.27
# 3                932.0           594.0  365              41.05
# 4                978.4           825.5  360              44.30
# ...                ...             ...  ...                ...
# 1025             870.1           768.3   28              44.28
# 1026             817.9           813.4   28              31.18
# 1027             892.4           780.0   28              23.70
# 1028             989.6           788.9   28              32.77
# 1029             864.5           761.5   28              32.40
#
# [1030 rows x 9 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse_Aggregate  Fine_Aggregate  Age  Concrete_strength
# 0               1040.0           676.0   28              79.99
# 1               1055.0           676.0   28              61.89
# 2                932.0           594.0  270              40.27
# 3                932.0           594.0  365              41.05
# 4                978.4           825.5  360              44.30
# ...                ...             ...  ...                ...
# 1025             870.1           768.3   28              44.28
# 1026             817.9           813.4   28              31.18
# 1027             892.4           780.0   28              23.70
# 1028             989.6           788.9   28              32.77
# 1029             864.5           761.5   28              32.40
#
# [1030 rows x 9 columns]>

# %%
df.dtypes
# Out:
# Cement                float64
# Blast_Furnace_Slag    float64
# Fly_Ash               float64
# Water                 float64
# Superplasticizer      float64
# Coarse_Aggregate      float64
# Fine_Aggregate        float64
# Age                     int64
# Concrete_strength     float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of       Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse_Aggregate  Fine_Aggregate  Age  Concrete_strength
# 0               1040.0           676.0   28              79.99
# 1               1055.0           676.0   28              61.89
# 2                932.0           594.0  270              40.27
# 3                932.0           594.0  365              41.05
# 4                978.4           825.5  360              44.30
# ...                ...             ...  ...                ...
# 1025             870.1           768.3   28              44.28
# 1026             817.9           813.4   28              31.18
# 1027             892.4           780.0   28              23.70
# 1028             989.6           788.9   28              32.77
# 1029             864.5           761.5   28              32.40
#
# [1030 rows x 9 columns]>

# %%
df.columns
# Out:
# Index(['Cement', 'Blast_Furnace_Slag', 'Fly_Ash', 'Water', 'Superplasticizer',
#        'Coarse_Aggregate', 'Fine_Aggregate', 'Age', 'Concrete_strength'],
#       dtype='object')

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.describe()
# Out:
#             Cement  Blast_Furnace_Slag      Fly_Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse_Aggregate  Fine_Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#        Concrete_strength
# count        1030.000000
# mean           35.817961
# std            16.705742
# min             2.330000
# 25%            23.710000
# 50%            34.445000
# 75%            46.135000
# max            82.600000

# %% [markdown]
# # CHECKING MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast_Furnace_Slag    0
# Fly_Ash               0
# Water                 0
# Superplasticizer      0
# Coarse_Aggregate      0
# Fine_Aggregate        0
# Age                   0
# Concrete_strength     0
# dtype: int64

# %% [markdown]
# # CHECKING DUPLICATE VALUES

# %%
# Assuming your DataFrame is named df
duplicate_count = df.duplicated().sum()

# Display the count of duplicate rows in the DataFrame
print("Number of Duplicate Rows:", duplicate_count)
# Out:
# Number of Duplicate Rows: 25

# %%
# Assuming your DataFrame is named df
duplicate_rows = df[df.duplicated()]

# Display the rows with duplicate values
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
#      Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 77    425.0               106.3      0.0  153.5              16.5
# 80    425.0               106.3      0.0  153.5              16.5
# 86    362.6               189.0      0.0  164.9              11.6
# 88    362.6               189.0      0.0  164.9              11.6
# 91    362.6               189.0      0.0  164.9              11.6
# 100   425.0               106.3      0.0  153.5              16.5
# 103   425.0               106.3      0.0  153.5              16.5
# 109   362.6               189.0      0.0  164.9              11.6
# 111   362.6               189.0      0.0  164.9              11.6
# 123   425.0               106.3      0.0  153.5              16.5
# 126   425.0               106.3      0.0  153.5              16.5
# 132   362.6               189.0      0.0  164.9              11.6
# 134   362.6               189.0      0.0  164.9              11.6
# 137   362.6               189.0      0.0  164.9              11.6
# 146   425.0               106.3      0.0  153.5              16.5
# 149   425.0               106.3      0.0  153.5              16.5
# 155   362.6               189.0      0.0  164.9              11.6
# 157   362.6               189.0      0.0  164.9              11.6
# 160   362.6               189.0      0.0  164.9              11.6
# 169   425.0               106.3      0.0  153.5              16.5
# 172   425.0               106.3      0.0  153.5              16.5
# 177   362.6               189.0      0.0  164.9              11.6
# 179   362.6               189.0      0.0  164.9              11.6
# 182   362.6               189.0      0.0  164.9              11.6
# 809   252.0                 0.0      0.0  185.0               0.0
#
#      Coarse_Aggregate  Fine_Aggregate  Age  Concrete_strength
# 77              852.1           887.1    3              33.40
# 80              852.1           887.1    3              33.40
# 86              944.7           755.8    3              35.30
# 88              944.7           755.8    3              35.30
# 91              944.7           755.8    3              35.30
# 100             852.1           887.1    7              49.20
# 103             852.1           887.1    7              49.20
# 109             944.7           755.8    7              55.90
# 111             944.7           755.8    7              55.90
# 123             852.1           887.1   28              60.29
# 126             852.1           887.1   28              60.29
# 132             944.7           755.8   28              71.30
# 134             944.7           755.8   28              71.30
# 137             944.7           755.8   28              71.30
# 146             852.1           887.1   56              64.30
# 149             852.1           887.1   56              64.30
# 155             944.7           755.8   56              77.30
# 157             944.7           755.8   56              77.30
# 160             944.7           755.8   56              77.30
# 169             852.1           887.1   91              65.20
# 172             852.1           887.1   91              65.20
# 177             944.7           755.8   91              79.30
# 179             944.7           755.8   91              79.30
# 182             944.7           755.8   91              79.30
# 809            1111.0           784.0   28              19.69

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1005, 9)

# %% [markdown]
# # CHANGE DATATYPES

# %%
float_columns = []
for i in df.columns:
    if df[i].dtype == 'float64':
        float_columns.append(i)
    
print(float_columns)
# Out:
# ['Cement', 'Blast_Furnace_Slag', 'Fly_Ash', 'Water', 'Superplasticizer', 'Coarse_Aggregate', 'Fine_Aggregate', 'Concrete_strength']

# %%
for i in float_columns:
    df[i] = df[i].astype(int)

# %%
df.dtypes
# Out:
# Cement                int32
# Blast_Furnace_Slag    int32
# Fly_Ash               int32
# Water                 int32
# Superplasticizer      int32
# Coarse_Aggregate      int32
# Fine_Aggregate        int32
# Age                   int64
# Concrete_strength     int32
# dtype: object

# %%
df.head(5)
# Out:
#    Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0     540                   0        0    162                 2
# 1     540                   0        0    162                 2
# 2     332                 142        0    228                 0
# 3     332                 142        0    228                 0
# 4     198                 132        0    192                 0
#
#    Coarse_Aggregate  Fine_Aggregate  Age  Concrete_strength
# 0              1040             676   28                 79
# 1              1055             676   28                 61
# 2               932             594  270                 40
# 3               932             594  365                 41
# 4               978             825  360                 44

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # 1.Univariate Analysis

# %% [markdown]
# ## 1.1 Boxplot

# %%
for i in df.columns:
    # Create a boxplot
    plt.figure(figsize=(8, 6))
    sns.boxplot(df[i])
    plt.title('Boxplot of {}'.format(i))
    plt.show()

# %% [markdown]
# ## 1.2 HISTOGRAM

# %%
for i in df.columns:
    # Create a histogram
    plt.figure(figsize=(8, 6))
    sns.histplot(df[i], bins=5, kde=False, color='skyblue')
    plt.title('Histogram Example {}'.format(i))
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ## 1.3 SKEWNESS AND KURTOSIS

# %%
from scipy.stats import skew, kurtosis

# Assuming 'data' is your dataset
skewness = skew(df)
kurt = kurtosis(df)

print(skewness)
print(kurt)
# Out:
# [ 0.56488264  0.85587067  0.49825931  0.03123594  1.08308196 -0.06291526
#  -0.25058821  3.24911503  0.39313592]
# [-0.43668367 -0.4065288  -1.36207983  0.16186757  2.06817969 -0.58394056
#  -0.11522448 11.8965698  -0.31256598]

# %% [markdown]
# ## 1.4 QQPLOT

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

for i in df.columns:
    # Create Q-Q plot
    fig, ax = plt.subplots(figsize=(8, 6))
    sm.qqplot(df[i], line='s', ax=ax)
    plt.title('Q-Q Plot {}'.format(i))
    plt.show()

# %% [markdown]
# # 2. BIVARIATE ANALYSIS

# %% [markdown]
# ## 2.1 SCATTERPLOT

# %%
x = df['Concrete_strength']
for i in df.columns:
    if i != 'Concrete_strength':
        # Scatter plot
        plt.scatter(x, df[i])
        plt.title('Scatter Plot of {} v/s concrete'.format(i))
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.show()

# %% [markdown]
# Observations:
#
# 1. Only Cement has linear related to my target variables

# %% [markdown]
# ## 2.2 LINEPLOT

# %%
x = df['Concrete_strength']
for i in df.columns:
    if i != 'Concrete_strength':

        # Line plot
        plt.plot(x, df[i], label='Line 1')
        plt.title('Line Plot of target variables v/s {}'.format(i))
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.legend()
        plt.show()

# %% [markdown]
# ## 2.3 CORRELATION ANALYSIS

# %%
# Adjust the figure size as per your preference
plt.figure(figsize=(12, 10))  

# Compute the correlation matrix using the 'spearman' method
correlation_matrix = df.corr(method='spearman')


sns.heatmap (data=correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

# Set the title and axis labels
plt.title('Correlation Heatmap')
plt.tight_layout()  # Improve the spacing between the heatmap and the axis labels

plt.show()

# %%
corr = df.corr()
target_corr = corr['Concrete_strength'].drop('Concrete_strength')

#Sort corelation in descending order
target_corr_sort = target_corr.sort_values(ascending = False)

#Plot Graphn
sns.heatmap(target_corr_sort.to_frame(), cmap = 'coolwarm', annot = True)
plt.show()

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
class eda(object):
    def univariate_analysis(df):
        print('1.UNIVARIATE ANALYSIS')
        print('1.1 BOXPLOT-------------------------------------------------')
        for i in df.columns:
            # Create a boxplot
            plt.figure(figsize=(8, 6))
            sns.boxplot(df[i])
            plt.title('Boxplot of {}'.format(i))
            plt.show()
    
        print('=========================================================================')
        print('1.2 HISTOGRAM ------------------------------------------------')
        for i in df.columns:
            # Create a histogram
            plt.figure(figsize=(8, 6))
            sns.histplot(df[i], bins=5, kde=False, color='skyblue')
            plt.title('Histogram Example {}'.format(i))
            plt.xlabel('Values')
            plt.ylabel('Frequency')
            plt.show()
            
        print('==========================================================================')
        print('1.3 QQ PLOT----------------------------------------------------')
        for i in df.columns:
            # Create Q-Q plot
            fig, ax = plt.subplots(figsize=(8, 6))
            sm.qqplot(df[i], line='s', ax=ax)
            plt.title('Q-Q Plot {}'.format(i))
            plt.show()
            
        print('==========================================================================') 
    def bivariate_analysis(df,x):
        print('2. BIVARIATE ANALYSIS')
        print('2.1 SCATTER PLOT-----------------------------------------------')
        for i in df.columns:
            if i != 'Concrete_strength':
                # Scatter plot
                plt.scatter(df[x], df[i])
                plt.title('Scatter Plot of {} v/s concrete'.format(i))
                plt.xlabel('X-axis')
                plt.ylabel('Y-axis')
                plt.show()
                
                
        print('==========================================================================') 
    def correlarion(df, x):
        print('3.1 CORRELATION ANALYSIS-----------------------------------------------')
        # Adjust the figure size as per your preference
        plt.figure(figsize=(12, 10))  

        # Compute the correlation matrix using the 'spearman' method
        correlation_matrix = df.corr(method='spearman')


        sns.heatmap (data=correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

        # Set the title and axis labels
        plt.title('Correlation Heatmap')
        plt.tight_layout()  # Improve the spacing between the heatmap and the axis labels

        plt.show()
        
        corr = df.corr()
        target_corr = corr[x].drop(x)

        #Sort corelation in descending order
        target_corr_sort = target_corr.sort_values(ascending = False)

        #Plot Graphn
        sns.heatmap(target_corr_sort.to_frame(), cmap = 'coolwarm', annot = True)
        plt.show()

# %%
target = 'Concrete_strength'

# %%
eda.correlarion(df, target)
# Out:
# 3.1 CORRELATION ANALYSIS-----------------------------------------------

# %% [markdown]
# # DATA TRANSFORMATION

# %% [markdown]
# ## 1. STANDARD SCALING

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(df)

# Convert the scaled data back to a DataFrame
ss_df = pd.DataFrame(scaled_data, columns=df.columns)

# Display the scaled DataFrame
print("Original DataFrame:")
print(df)
print("\nScaled DataFrame:")
print(ss_df)
# Out:
# Original DataFrame:
#       Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0        540                   0        0    162                 2
# 1        540                   0        0    162                 2
# 2        332                 142        0    228                 0
# 3        332                 142        0    228                 0
# 4        198                 132        0    192                 0
# ...      ...                 ...      ...    ...               ...
# 1025     276                 116       90    179                 8
# 1026     322                   0      115    196                10
# 1027     148                 139      108    192                 6
# 1028     159                 186        0    175                11
# 1029     260                 100       78    200                 8
#
#       Coarse_Aggregate  Fine_Aggregate  Age  Concrete_strength
# 0                 1040             676   28                 79
# 1                 1055             676   28                 61
# 2                  932             594  270                 40
# 3                  932             594  365                 41
# 4                  978             825  360                 44
# ...                ...             ...  ...                ...
# 1025               870             768   28                 44
# 1026               817             813   28                 31
# 1027               892             780   28                 23
# 1028               989             788   28                 32
# 1029               864             761   28                 32
#
# [1030 rows x 9 columns]
#
# Scaled DataFrame:
#         Cement  Blast_Furnace_Slag   Fly_Ash     Water  Superplasticizer  \
# 0     2.478287           -0.856420 -0.846791 -0.898619         -0.675802
# 1     2.478287           -0.856420 -0.846791 -0.898619         -0.675802
# 2     0.488510            0.792280 -0.846791  2.177629         -1.018951
# 3     0.488510            0.792280 -0.846791  2.177629         -1.018951
# 4    -0.793366            0.676174 -0.846791  0.499675         -1.018951
# ...        ...                 ...       ...       ...               ...
# 1025 -0.047200            0.490405  0.563311 -0.106252          0.353643
# 1026  0.392847           -0.856420  0.955006  0.686115          0.696791
# 1027 -1.271678            0.757448  0.845331  0.499675          0.010494
# 1028 -1.166449            1.303144 -0.846791 -0.292692          0.868365
# 1029 -0.200259            0.304636  0.375297  0.872554          0.353643
#
#       Coarse_Aggregate  Fine_Aggregate       Age  Concrete_strength
# 0             0.867035       -1.214996 -0.279733           2.616045
# 1             1.060160       -1.214996 -0.279733           1.538019
# 2            -0.523461       -2.238930  3.553066           0.280322
# 3            -0.523461       -2.238930  5.057677           0.340212
# 4             0.068787        0.645565  4.978487           0.519883
# ...                ...             ...       ...                ...
# 1025         -1.321709       -0.066193 -0.279733           0.519883
# 1026         -2.004083        0.495721 -0.279733          -0.258691
# 1027         -1.038460        0.083651 -0.279733          -0.737814
# 1028          0.210412        0.183547 -0.279733          -0.198801
# 1029         -1.398959       -0.153602 -0.279733          -0.198801
#
# [1030 rows x 9 columns]

# %%
eda.correlarion(ss_df, target)
# Out:
# 3.1 CORRELATION ANALYSIS-----------------------------------------------

# %%
eda.bivariate_analysis(ss_df, target)
# Out:
# 2. BIVARIATE ANALYSIS
# 2.1 SCATTER PLOT-----------------------------------------------
# ==========================================================================

# %% [markdown]
# ## 1.2 MIN MAX SCALING

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Initialize the StandardScaler
scaler = MinMaxScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(df)

# Convert the scaled data back to a DataFrame
mm_df = pd.DataFrame(scaled_data, columns=df.columns)

# Display the scaled DataFrame
print("Original DataFrame:")
print(df.head(4))
print("\nScaled DataFrame:")
print(mm_df.head(4))
# Out:
# Original DataFrame:
#    Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0     540                   0        0    162                 2
# 1     540                   0        0    162                 2
# 2     332                 142        0    228                 0
# 3     332                 142        0    228                 0
#
#    Coarse_Aggregate  Fine_Aggregate  Age  Concrete_strength
# 0              1040             676   28                 79
# 1              1055             676   28                 61
# 2               932             594  270                 40
# 3               932             594  365                 41
#
# Scaled DataFrame:
#      Cement  Blast_Furnace_Slag  Fly_Ash     Water  Superplasticizer  \
# 0  1.000000            0.000000      0.0  0.325397            0.0625
# 1  1.000000            0.000000      0.0  0.325397            0.0625
# 2  0.525114            0.395543      0.0  0.849206            0.0000
# 3  0.525114            0.395543      0.0  0.849206            0.0000
#
#    Coarse_Aggregate  Fine_Aggregate       Age  Concrete_strength
# 0          0.694767         0.20603  0.074176             0.9625
# 1          0.738372         0.20603  0.074176             0.7375
# 2          0.380814         0.00000  0.739011             0.4750
# 3          0.380814         0.00000  1.000000             0.4875

# %%
eda.correlarion(mm_df, target)
# Out:
# 3.1 CORRELATION ANALYSIS-----------------------------------------------

# %%
eda.bivariate_analysis(mm_df, target)
# Out:
# 2. BIVARIATE ANALYSIS
# 2.1 SCATTER PLOT-----------------------------------------------
# ==========================================================================

# %% [markdown]
# # MODEL TRAINING

# %%
# Basic Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, train_test_split
import warnings

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
# Create a DataFrame with features (X) by dropping the target column
print(df.shape)
x = df.drop(columns=['Concrete_strength'],axis=1)
print(x.shape)

# Create a DataFrame with the target variable (y)
y = df[target]
print(y.shape)
# Out:
# (1030, 9)
# (1030, 8)
# (1030,)

# %%
print(x.head(3))
# Out:
#    Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0     540                   0        0    162                 2
# 1     540                   0        0    162                 2
# 2     332                 142        0    228                 0
#
#    Coarse_Aggregate  Fine_Aggregate  Age
# 0              1040             676   28
# 1              1055             676   28
# 2               932             594  270

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "AdaBoost Regressor": AdaBoostRegressor()
}
model_list = []
r2_list =[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 10.5150
# - Mean Absolute Error: 8.3376
# - R2 Score: 0.6111
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 9.7725
# - Mean Absolute Error: 7.7208
# - R2 Score: 0.6281
# ===================================
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 10.5180
# - Mean Absolute Error: 8.3418
# - R2 Score: 0.6109
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 9.7739
# - Mean Absolute Error: 7.7199
# - R2 Score: 0.6280
# ===================================
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 10.5150
# - Mean Absolute Error: 8.3376
# - R2 Score: 0.6111
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 9.7725
# - Mean Absolute Error: 7.7208
# - R2 Score: 0.6281
# ===================================
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 7.5201
# - Mean Absolute Error: 5.6000
# - R2 Score: 0.8011
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 8.2331
# - Mean Absolute Error: 6.4447
# - R2 Score: 0.7360
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Root Mean Squared Error: 0.9511
# - Mean Absolute Error: 0.0947
# - R2 Score: 0.9968
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.3303
# - Mean Absolute Error: 4.1359
# - R2 Score: 0.8440
# ===================================
#
#
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 2.0118
# - Mean Absolute Error: 1.3074
# - R2 Score: 0.9858
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 5.6127
# - Mean Absolute Error: 3.9113
# - R2 Score: 0.8773
# ===================================
#
#
# AdaBoost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 6.9868
# - Mean Absolute Error: 5.8617
# - R2 Score: 0.8283
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 7.7408
# - Mean Absolute Error: 6.4285
# - R2 Score: 0.7667
# ===================================

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name  R2_Score
# 5  Random Forest Regressor  0.877327
# 4            Decision Tree  0.843952
# 6       AdaBoost Regressor  0.766667
# 3    K-Neighbors Regressor  0.736043
# 2                    Ridge  0.628109
# 0        Linear Regression  0.628109
# 1                    Lasso  0.627998

# %% [markdown]
# ### RANDOM FOREST REGRESSOR

# %%
RF_model = RandomForestRegressor(random_state=42)
RF_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = RF_model.predict(X_test)

# Calculate R^2 score
score = r2_score(y_test, y_pred) * 100
print("Accuracy of the model is %.2f" % score)
# Out:
# Accuracy of the model is 88.36

# %%
plt.scatter(y_test,y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted');

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})
pred_df
# Out:
#      Actual Value  Predicted Value  Difference
# 31             52        51.420000    0.580000
# 109            55        40.109500   14.890500
# 136            74        70.040000    3.960000
# 88             35        34.270000    0.730000
# 918            10        10.410000   -0.410000
# ..            ...              ...         ...
# 482            56        55.405667    0.594333
# 545            18        23.090000   -5.090000
# 110            38        33.220000    4.780000
# 514            74        67.090000    6.910000
# 602            35        36.010000   -1.010000
#
# [206 rows x 3 columns]
